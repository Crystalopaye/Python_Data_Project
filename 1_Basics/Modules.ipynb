# %% [markdown]
# # MODULES

# %%
import my_module

my_module.skill("Python")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1525/2456736158.py in <cell line: 0>()
# ----> 1 import my_module
#       2
#       3 my_module.skill("Python")
#
# ModuleNotFoundError: No module named 'my_module'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from job_analyzer import *

calculate_salary(100_000)
calculate_bonus(110000, 100000)

# %%
help(calculate_salary)

# %% [markdown]
# ### Statistics Module

# %%
salary_list = [100_000, 101_000, 90_000, 37000, 50_000]

# %%
from statistics import mean, mode, median

print(mean(salary_list))
print(mode(salary_list))
median(salary_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1525/1038659698.py in <cell line: 0>()
#       1 from statistics import mean, mode, median
#       2
# ----> 3 print(mean(salary_list))
#       4 print(mode(salary_list))
#       5 median(salary_list)
#
# NameError: name 'salary_list' is not defined

# %%
import statistics as stats

# Sample sales data
daily_sales = [1250, 1320, 1410, 1230, 1350, 1458, 1390, 1310]

# %%
# Basic statistics
print("Basic Statistics (built-in module):")
print(f" Mean (average): ${stats.mean(daily_sales):.2f} ")
print(f" Median (middle value): ${stats.median(daily_sales):.2f} ")
print(f" Mode(most frequent): ${stats.mode(daily_sales):.2f}")
print(f"  Variance: ${stats.variance(daily_sales):.2f}")
print(f"  Standard deviation: ${stats.stdev(daily_sales):.2f}")

# %% [markdown]
# # CLEANING DATA

# %%
# Given a list of dictionaries, each representing a different role, where each dictionary contains a key 'job_skills' with a string value representing a list of skills, and a `'job_date' represented also in a string value.

# Turn the 'job_date' from a string value to a date time object.
# Turn the 'job_skills' from a string value to an actual list object.

data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2023-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python', 'TensorFlow', 'Deep Learning']", 'job_date': '2023-05-15'},
    {'job_title': 'Data Analyst', 'job_skills': "['SQL', 'R', 'Tableau']", 'job_date': '2023-05-10'},
    {'job_title': 'Business Intelligence Developer', 'job_skills': "['SQL', 'PowerBI', 'Data Warehousing']", 'job_date': '2023-05-08'},
    {'job_title': 'Data Engineer', 'job_skills': "['Python', 'Spark', 'Hadoop']", 'job_date': '2023-05-18'},
    {'job_title': 'AI Specialist', 'job_skills': "['Python', 'PyTorch', 'AI Ethics']", 'job_date': '2023-05-20'}
]

# %%
from datetime import datetime

# %%
datetime.now()

# %%
type(data_science_jobs [0]["job_date"])

# %%
test_date = data_science_jobs [0]["job_date"]

# %%
print(datetime.strptime(test_date, "%Y-%m-%d" ))

# %%
import ast
for job in data_science_jobs:
   job["job_date"] = datetime.strptime(test_date, "%Y-%m-%d" )
   job["job_skills"] = ast.literal_eval(job["job_skills"])

# %%
data_science_jobs

# %% [markdown]
# # LIBRARY

# %%
file = open("/content/sample_data/california_housing_test.csv")
content = file.read()
file.close()

# %%
# Using pandas to read a csv file
import pandas as pd
contents = pd.read_csv("/content/sample_data/california_housing_test.csv")
contents['longitude'].sum()

# %%
import pyjokes
pyjokes.get_joke()

# %% [markdown]
# # CLASSES

# %%
class LukesList:
    def __init__(self):
        """Initialize an empty list."""
        self._items = []

    def add(self, item):
        """Add an item to the end of the list."""
        self._items.append(item)

    def __getitem__(self, index):
        """Retrieve an item by index."""
        return self._items[index]

    def __setitem__(self, index, value):
        """Set an item at a specific index."""
        self._items[index] = value

    def __repr__(self):
        """Return a string representation of the list."""
        return str(self._items)

    def __len__(self):
        """Return the length of the list."""
        return len(self._items)

# %%
my_list = LukesList()

# %%
my_list

# %%
my_list.add("Data Nerd")

# %%
my_list

# %%
my_list.add("Finance")

# %%
my_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1525/376848641.py in <cell line: 0>()
# ----> 1 my_list
#
# NameError: name 'my_list' is not defined

# %%
len(my_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1525/2292191500.py in <cell line: 0>()
# ----> 1 len(my_list)
#
# NameError: name 'my_list' is not defined

# %% [markdown]
# ### Building a grouo of Functions into a Class

# %%
def calculate_salary(base_salary, bonus_rate=.1):
  """
  Calculate the total salary based on the base salary and bonus rate.

  Args:
    base_salary (float): The base salary.
    bonus_rate (float): The bonus rate. Default is .1.

  Returns:
    float: The total salary.
  """
  return base_salary * (1 + bonus_rate)

def calculate_bonus(total_salary, base_salary):
  """
  Calculate the bonus rate based on the total salary and base salary.

  Args:
    total_salary (float): The total salary.
    base_salary (float): The base salary.

  Returns:
    float: The bonus rate.
  """
  return (total_salary - base_salary) / base_salary

# %%
class BaseSalary:
  def __init__(self, base_salary, bonus_rate=0.1, symbol="$"):
    self.base_salary = base_salary
    self.bonus_rate = bonus_rate
    self.symbol = symbol
    self.total_salary = base_salary * (1 + bonus_rate)
    self.bonus = self.total_salary - self.base_salary

  def __repr__(self):
    return f'{self.symbol}{self.base_salary:,.0f}'

  def show_salary(self):
    return f'{self.symbol}{self.total_salary:,.0f}'

  def show_bonus(self):
    return f'{self.symbol}{self.bonus:,.0f}'

# %%
data_salary = BaseSalary(100000, .2)

# %%
data_salary

# %%
data_salary.show_salary()

# %%
# Creating the class
class BaseSalary:
  def __init__(self, base_salary, bonus_rate=0.1, symbol="$"):
    self.base_salary = base_salary
    self.bonus_rate = bonus_rate
    self.symbol = symbol
    self.total_salary = base_salary * (1 + bonus_rate)
    self.bonus = self.total_salary - self.base_salary

  def __repr__(self):
    return f"{self.symbol}{self.base_salary:,.0f}"

  def show_salary(self):
    return f"{self.symbol}{self.total_salary:,.0f}"

  def show_bonus(self):
     return f"{self.symbol}{self.bonus:,.0f}"

# %%
salary = BaseSalary(100000)

salary.symbol

# %%
salary
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1525/1275587642.py in <cell line: 0>()
# ----> 1 salary
#
# NameError: name 'salary' is not defined

# %%
salary.show_salary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1525/1314758227.py in <cell line: 0>()
# ----> 1 salary.show_salary()
#
# NameError: name 'salary' is not defined

# %%
salary.show_bonus()

# %% [markdown]
# ### Class Examples

# %%
# Create a class named DataScienceJobs, use the __init__() function to assign values for jobs

# %%
class DataScienceJobs:
  def __init__(self, jobs):
    self.jobs = jobs

  def __str__(self):

    jobs_str = "Data Science Jobs:\n"
    for job in self.jobs:
      jobs_str += f"- {job["job_title"]}: {job["job_skills"]}\n"
    return jobs_str

# %%
data_science_jobs = [
    {"job_title": "Data Scientist", "job_skills": "Python, SQL,Machine Learning"},
    {"job_title": "Data Analyst", "job_skills": "SQL, Excel, Python"},
    {"job_title": "Machine Learning Engineer", "job_skills": "Python, TensorFlow, Keras"}
]

# %%
jobs_list = DataScienceJobs(data_science_jobs)

# %%
print(jobs_list)

# %% [markdown]
# ### Object Methods

# %%
class DataScienceJobList:
  def __init__(self, jobs):
    self.jobs = jobs

  def __str__(self):
    jobs_str = "Data Science Jobs:\n"
    for job in self.jobs:
      jobs_str += f"- {job["job_title"]}: {",".join(job["job_skills"])}\n"
    return jobs_str

  def split_skills(self):
    for job in self.jobs:
      job["job_skills"] = job["job_skills"].split(", ")

# %%
jobs_list = DataScienceJobList(data_science_jobs)
jobs_list.split_skills()
print(jobs_list)

# %% [markdown]
# ### Extras

# %%
class DataScienceJobsList:
    def __init__(self, jobs):
        self.jobs = jobs

    def __str__(self):
        jobs_str = 'Data Science Jobs:\n'
        for job in self.jobs:
            jobs_str += f"- {job['job_title']}: {', '.join(job['job_skills'])}\n"
        return jobs_str

    def split_skills(self):
        for job in self.jobs:
            job['job_skills'] = job['job_skills'].split(', ')

# %%
jobs_list = DataScienceJobsList(data_science_jobs)
print(jobs_list)
# Out:
# Data Science Jobs:
# - Data Scientist: P, y, t, h, o, n, ,,  , S, Q, L, ,, M, a, c, h, i, n, e,  , L, e, a, r, n, i, n, g
# - Data Analyst: S, Q, L, ,,  , E, x, c, e, l, ,,  , P, y, t, h, o, n
# - Machine Learning Engineer: P, y, t, h, o, n, ,,  , T, e, n, s, o, r, F, l, o, w, ,,  , K, e, r, a, s
